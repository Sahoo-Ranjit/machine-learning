# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-100-popular-movies-from-2003-to-2022-imdb/movies.csv

# %%
mov = pd.read_csv("/kaggle/input/top-100-popular-movies-from-2003-to-2022-imdb/movies.csv")

# %%
mov
# Out:
#                                            Title  Rating  Year     Month  \
# 0                       Avatar: The Way of Water     7.8  2022  December
# 1                 Guillermo del Toro's Pinocchio     7.6  2022  December
# 2                                   Bullet Train     7.3  2022    August
# 3                      The Banshees of Inisherin     7.8  2022  November
# 4                                          M3gan     6.4  2022  December
# ...                                          ...     ...   ...       ...
# 1995                       A Tale of Two Sisters     7.1  2003      June
# 1996  Lara Croft Tomb Raider: The Cradle of Life     5.5  2003      July
# 1997                                     Gothika     5.8  2003  November
# 1998                   Ong-Bak: The Thai Warrior     7.1  2003  February
# 1999                                  Open Water     5.8  2003    August
#
#      Certificate Runtime                           Directors  \
# ...

# %%
mov.isnull().sum()
# Out:
# Title                 0
# Rating                1
# Year                  0
# Month                 0
# Certificate          34
# Runtime               0
# Directors             0
# Stars                 0
# Genre                 0
# Filming_location      0
# Budget                0
# Income                0
# Country_of_origin     0
# dtype: int64

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              2000 non-null   object
#  1   Rating             1999 non-null   float64
#  2   Year               2000 non-null   int64
#  3   Month              2000 non-null   object
#  4   Certificate        1966 non-null   object
#  5   Runtime            2000 non-null   object
#  6   Directors          2000 non-null   object
#  7   Stars              2000 non-null   object
#  8   Genre              2000 non-null   object
#  9   Filming_location   2000 non-null   object
#  10  Budget             2000 non-null   object
#  11  Income             2000 non-null   object
#  12  Country_of_origin  2000 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 203.2+ KB

# %%
mov['Certificate'] = mov['Certificate'].fillna(mov['Certificate'].mode()[0])

# %%
mov.isnull().sum()
# Out:
# Title                0
# Rating               1
# Year                 0
# Month                0
# Certificate          0
# Runtime              0
# Directors            0
# Stars                0
# Genre                0
# Filming_location     0
# Budget               0
# Income               0
# Country_of_origin    0
# dtype: int64

# %%
mov['Rating'].unique()
# Out:
# array([7.8, 7.6, 7.3, 6.4, 6.1, 6.9, 7.5, 6.6, 7. , 6.5, 6.7, 6.8, 5.8,
#        8.1, 6.2, 5.1, 8.4, 7.1, 7.2, 5.2, 7.7, 7.4, 8.5, 6.3, 8. , 4.4,
#        5.7, 5. , 4.2, 7.9, 4.7, 8.6, nan, 5.5, 5.4, 8.3, 3.6, 6. , 4.5,
#        5.9, 3.3, 8.2, 5.3, 4.9, 5.6, 4.8, 2.8, 3.5, 4. , 4.6, 3.4, 4.1,
#        4.3, 2.1, 3.8, 8.8, 3.2, 2.6, 9. , 1.9, 2.4, 3.7, 2.2])

# %%
mov['Rating'] = mov['Rating'].fillna(6.6)

# %%
mov.isnull().sum()
# Out:
# Title                0
# Rating               0
# Year                 0
# Month                0
# Certificate          0
# Runtime              0
# Directors            0
# Stars                0
# Genre                0
# Filming_location     0
# Budget               0
# Income               0
# Country_of_origin    0
# dtype: int64

# %%
mov.head()
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
# 2                    Bullet Train     7.3  2022    August           R     127
# 3       The Banshees of Inisherin     7.8  2022  November           R     114
# 4                           M3gan     6.4  2022  December       PG-13     102
#
#                             Directors  \
# 0                       James Cameron
# 1  Guillermo del Toro, Mark Gustafson
# 2                        David Leitch
# 3                     Martin McDonagh
# 4                    Gerard Johnstone
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2  Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# ...

# %%
mov[mov['Filming_location'] == 'India']
# Out:
#                                     Title  Rating  Year     Month Certificate  \
# 84                             Drishyam 2     8.6  2022  November           R
# 668                                  Lion     8.0  2016   January       PG-13
# 748                              Drishyam     8.2  2015      July   Not Rated
# 1005                The Dark Knight Rises     8.4  2012      July       PG-13
# 1011                     Zero Dark Thirty     7.4  2012   January           R
# 1142       The Best Exotic Marigold Hotel     7.2  2011       May       PG-13
# 1316                             3 Idiots     8.4  2009  December       PG-13
# 1411  The Curious Case of Benjamin Button     7.8  2008  December       PG-13
# 1435                  Slumdog Millionaire     8.0  2008  December           R
# 1561               The Darjeeling Limited     7.2  2007   October           R
# 1586                  Like Stars on Earth     8.4  2007  December          PG
# ...
